# %%
import pandas as pd

# 读取CSV文件
file_name = './datasets_FIX/FIX_deduplicated_mangoNews_Nums3000p_CategoryMerge_new_undersampled.csv'

# df = pd.read_csv('./datasets/deduplicated_mangoNews_Nums3000p_CategoryMerge_new_undersampled_Example.csv')
# 读取CSV文件
df = pd.read_csv(file_name,low_memory=False,lineterminator="\n",nrows=100)

# 查看数据的前几行
# print("前五行数据：")
# pd.set_option('display.max_rows', None)


# pd.reset_option('display.max_rows')
df.head()

# %%
import pandas as pd

# file_name = './datasets/deduplicated_mangoNews_Nums3000p_CategoryMerge_new_undersampled.csv'
# file_name = './datasets_FIX/FIX_deduplicated_mangoNews_Nums3000p_CategoryMerge_new_undersampled.csv'
# file_name = './datasets_FIX/FIX_deduplicated_mangoNews.csv' # use all data
file_name = './datasets_FIX/FIX_deduplicated_mangoNews_Nums3000p_CategoryMerge_new.csv' # use new data



# 读取CSV文件
df = pd.read_csv(file_name,low_memory=False,lineterminator="\n")

# %%
# 统计不同日期及对应的数据数量
# update :3.6 FIX data
# import pandas as pd

# # file_name = './datasets/deduplicated_mangoNews_Nums3000p_CategoryMerge_new_undersampled.csv'
# # file_name = './datasets_FIX/FIX_deduplicated_mangoNews_Nums3000p_CategoryMerge_new_undersampled.csv'
# file_name = './datasets_FIX/FIX_deduplicated_mangoNews.csv' # use all data


# # 读取CSV文件
# df = pd.read_csv(file_name,low_memory=False,lineterminator="\n")

# 将pub_time列转换为日期时间格式
df['pub_time'] = pd.to_datetime(df['pub_time'])

# 按照日期进行分组并统计每个日期分组中的记录数量
date_counts = df.groupby(df['pub_time'].dt.date).size()

# 将统计数据转换为DataFrame对象
date_counts_df = date_counts.reset_index(name='count')

# 按日期越新的顺序排序
date_counts_df = date_counts_df.sort_values(by='count', ascending=False)


# 保存统计数据到CSV文件
date_counts_df.to_csv('EachDate_Counts_FIX/FIX_Data_counts_new_sorted_newDATA.csv', index=False)

# pd.set_option('display.max_rows', None)
# 打印结果
print(date_counts_df)
# Out:
#         pub_time  count
# 0     1970-01-01   8353
# 2578  2023-10-28    498
# 2579  2023-10-29    461
# 2522  2023-08-31    442
# 2288  2023-01-06    441
# ...          ...    ...
# 76    2016-06-19      1
# 25    2013-05-20      1
# 77    2016-06-23      1
# 15    2013-01-02      1
# 79    2016-07-28      1
#
# [2622 rows x 2 columns]

# %%
# 提取最新的10天的新闻：2023-12-02-2023-12-11
# update :3.6 FIX data
# import pandas as pd


# # file_name = './datasets/deduplicated_mangoNews_Nums3000p_CategoryMerge_new_undersampled.csv'
# # file_name = './datasets_FIX/FIX_deduplicated_mangoNews_Nums3000p_CategoryMerge_new_undersampled.csv'
# file_name = './datasets_FIX/FIX_deduplicated_mangoNews.csv' # use all data


# # 读取CSV文件
# df = pd.read_csv(file_name,low_memory=False,lineterminator="\n")

# 将pub_time列转换为日期时间格式
df['pub_time'] = pd.to_datetime(df['pub_time'])

# 筛选日期在2023-12-02至2023-12-11之间的数据
# filtered_df = df[(df['pub_time'] >= '2023-12-02') & (df['pub_time'] <= '2023-12-11')]
# only 20231202
filtered_df = df[(df['pub_time'] == '2023-12-02')]


# 按照日期进行排序
sorted_df = filtered_df.sort_values(by='pub_time')

# 将结果保存到新的CSV文件中
# sorted_df.to_csv('./Data231202-231211_FIX/Data231202-231211_allDATA.csv', index=False) # FIX
# sorted_df.to_csv('./Data231202-231211_FIX/Data231202_allDATA.csv', index=False) # FIX
sorted_df.to_csv('./Data231202-231211_FIX/Data231202_newDATA.csv', index=False) # FIX


# 打印结果
# 196613         1779  49bee72f0e18f8d4aa2ac2657c9f6ac5\r
# 196611         1779  baa6e46575deaeee17e43b4b95807390\r
# 176385         1779  65320b86c02eec272653a29bd675309e\r
# 176383         1779  db2a14dcd7b8b592a258b9e1ad6395a0\r
# ...             ...                                 ...
# 137841         1779  c4d8b270b5c4dbe28c635c0cbd88c6fa\r
# 137839         1779  426cb05250a01c2ab15acb8def3d7398\r
# 132245         1779  79d56fedd46475fffea396e044098ed1\r
# 132240         1779  59c44610005ad03ac21ae9010faf9eef\r
# 399252         1779  382968b18ebf464e4d1eca042e08528a\r
#
# [82 rows x 14 columns]

# %%
import pandas as pd

file_name = './datasets/deduplicated_mangoNews_Nums3000p_CategoryMerge_new_undersampled.csv'

# 读取CSV文件
df = pd.read_csv(file_name,low_memory=False,lineterminator="\n")

# 统计category2列不为空的行数
non_empty_rows = df['category2'].notna().sum()

print("category2列不为空的行数为:", non_empty_rows)
# Out:
# category2列不为空的行数为: 5114

# %%
import pandas as pd

# 读取原始CSV文件
data = pd.read_csv('Data231202-231211.csv')
# data.head()

# 添加从0开始的序号列
data['index'] = range(len(data))

# 提取指定列
selected_columns = ['index','id', 'title', 'body', 'category1', 'category2','pub_time']
selected_data = data[selected_columns]
print(selected_data.iloc[0])

# 将修改后的数据保存到新文件中
new_file_path = 'Data231202-231211_pure.csv'
selected_data.to_csv(new_file_path, index=False)
selected_data.head()
# Out:
# index                                                        0
# id                                                    19648628
# title                           \n\nহিরোর হিরোইজমের পূর্বাপর\n
# body         বিএনপির এমপিদের পদত্যাগে শূন্য হওয়া ছয়টি সংসদী...
# category1                                             অন্যান্য
# category2                                                  NaN
# pub_time                                   2023-12-02 00:00:00
# Name: 0, dtype: object
#    index        id                                              title  \
# 0      0  19648628                     \n\nহিরোর হিরোইজমের পূর্বাপর\n
# 1      1  17332797        ভারত সফরে অস্ট্রেলিয়ার ভরাডুবি, যা বললেন ভন
# 2      2  17380041  অপহরণে অভিযুক্ত সেই অসিত পালকে বহিষ্কার করল ছা...
# 3      3  17375674              ‘মলম বিতর্ক’ শাস্তি হলো ভারতীয় তারকার
# 4      4  19649171  \n\nআড়াইহাজারে সংঘর্ষের ঘটনায় বিএনপির ১২০ নেতা...
#
#                                                 body category1 category2  \
# 0  বিএনপির এমপিদের পদত্যাগে শূন্য হওয়া ছয়টি সংসদী...  অন্যান্য       NaN
# 1  ভারত সফরে শুরুতেই হার দেখল অস্ট্রেলিয়া। চার ম্...  খেলাধুলা       NaN
# 2  জাহাঙ্গীরনগর বিশ্ববিদ্যালয় ছাত্রলীগের পরিবেশ ব...    শিক্ষা       NaN
# 3  অস্ট্রেলিয়ার বিপক্ষে নাগপুর টেস্টে আইসিসির আচর...  খেলাধুলা       NaN
# 4  নারায়ণগঞ্জের আড়াইহাজারে পদযাত্রা কর্মসূচিতে পু...     জাতীয়       NaN
#
#               pub_time
# 0  2023-12-02 00:00:00
# 1  2023-12-02 00:00:00
# 2  2023-12-02 00:00:00
# 3  2023-12-02 00:00:00
# 4  2023-12-02 00:00:00
